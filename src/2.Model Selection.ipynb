# %%
## importing Important modules
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")

# %%
print("Loading TF-IDF features...")
df = pd.read_csv("../Datasets/mbti_tfidf_features.csv")
# Out:
# Loading TF-IDF features...

# %%
df.columns
# Out:
# Index(['ability', 'able', 'abouti', 'absolute', 'absolutely',
#        'absolutely love', 'absorbed', 'abstract', 'absurd', 'abuse',
#        ...
#        'zodiac', 'zombie', 'zone', 'IE', 'NS', 'TF', 'JP', 'MBTI_type',
#        'original_posts', 'clean_posts'],
#       dtype='str', length=5007)

# %%
df.shape
# Out:
# (8675, 5007)

# %%
df.columns
# Out:
# Index(['ability', 'able', 'abouti', 'absolute', 'absolutely',
#        'absolutely love', 'absorbed', 'abstract', 'absurd', 'abuse',
#        ...
#        'zodiac', 'zombie', 'zone', 'IE', 'NS', 'TF', 'JP', 'MBTI_type',
#        'original_posts', 'clean_posts'],
#       dtype='str', length=5007)

# %%
models={
    "Logistic Regression" : LogisticRegression(n_jobs=-1),
    "Random Forest "      : RandomForestClassifier(n_jobs=-1),
    "AdaBoost Algorithm"  : AdaBoostClassifier(),
    "XG Boost"            : XGBClassifier(n_jobs=-1),
    "SVM"                 : SVC()
}

# %% [markdown]
# # Intuition (N) – Sensing (S)

# %%
print("Intuition (N) - Sensing (S)")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['NS']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
accuracy_score_NS=[]
for i in range(len(list(models))):
    model = list(models.values())[i]
    print(f"Prediction model : {list(models.keys())[i]}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print('='*35)
    print('\n')
    accuracy_score_NS.append(accuracy_score_NS)
# Out:
# Intuition (N) - Sensing (S)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.68      0.65       239
#            1       0.95      0.93      0.94      1496
#
#     accuracy                           0.90      1735
#    macro avg       0.78      0.81      0.79      1735
# weighted avg       0.90      0.90      0.90      1735
#
# Accuracy: 0.8968299711815562
# ===================================
#
#
# Prediction model : Random Forest
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.17      0.00      0.01       239
#            1       0.86      1.00      0.92      1496
#
#     accuracy                           0.86      1735
#    macro avg       0.51      0.50      0.47      1735
# weighted avg       0.77      0.86      0.80      1735
#
# Accuracy: 0.8599423631123919
# ===================================
#
#
# Prediction model : AdaBoost Algorithm
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.52      0.49       239
#            1       0.92      0.90      0.91      1496
#
#     accuracy                           0.85      1735
#    macro avg       0.69      0.71      0.70      1735
# weighted avg       0.86      0.85      0.85      1735
#
# Accuracy: 0.8489913544668588
# ===================================
#
#
# Prediction model : XG Boost
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.42      0.52       239
#            1       0.91      0.97      0.94      1496
#
#     accuracy                           0.89      1735
#    macro avg       0.80      0.70      0.73      1735
# weighted avg       0.88      0.89      0.88      1735
#
# Accuracy: 0.8939481268011528
# ===================================
#
#
# Prediction model : SVM
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.28      0.42       239
#            1       0.90      0.99      0.94      1496
#
#     accuracy                           0.89      1735
#    macro avg       0.83      0.64      0.68      1735
# weighted avg       0.88      0.89      0.87      1735
#
# Accuracy: 0.8899135446685879
# ===================================

# %% [markdown]
# # Introversion (I) – Extroversion (E)

# %%
print("Introversion (I) – Extroversion (E)")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['IE']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
for i in range(len(list(models))):
    model = list(models.values())[i]
    print(f"Prediction model : {list(models.keys())[i]}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print('='*35)
    print('\n')
# Out:
# Introversion (I) – Extroversion (E)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       400
#            1       0.91      0.90      0.90      1335
#
#     accuracy                           0.85      1735
#    macro avg       0.79      0.80      0.79      1735
# weighted avg       0.85      0.85      0.85      1735
#
# Accuracy: 0.8518731988472622
# ===================================
#
#
# Prediction model : Random Forest
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.12      0.20       400
#            1       0.79      0.98      0.87      1335
#
#     accuracy                           0.78      1735
#    macro avg       0.69      0.55      0.54      1735
# weighted avg       0.74      0.78      0.72      1735
#
# Accuracy: 0.7786743515850144
# ===================================
#
#
# Prediction model : AdaBoost Algorithm
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.53      0.57       400
#            1       0.86      0.90      0.88      1335
#
#     accuracy                           0.81      1735
#    macro avg       0.74      0.71      0.73      1735
# weighted avg       0.81      0.81      0.81      1735
#
# Accuracy: 0.8144092219020173
# ===================================
#
#
# Prediction model : XG Boost
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.56      0.63       400
#            1       0.88      0.93      0.90      1335
#
#     accuracy                           0.85      1735
#    macro avg       0.80      0.74      0.77      1735
# weighted avg       0.84      0.85      0.84      1735
#
# Accuracy: 0.8472622478386167
# ===================================
#
#
# Prediction model : SVM
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.43      0.57       400
#            1       0.85      0.97      0.91      1335
#
#     accuracy                           0.85      1735
#    macro avg       0.84      0.70      0.74      1735
# weighted avg       0.84      0.85      0.83      1735
#
# Accuracy: 0.8478386167146974
# ===================================

# %% [markdown]
# ## Judging (J) – Perceiving (P)

# %%
print("Judging (J) – Perceiving (P)")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['JP']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42) 
X_train, y_train = smote.fit_resample(X_train, y_train)
for i in range(len(list(models))):
    model = list(models.values())[i]
    print(f"Prediction model : {list(models.keys())[i]}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print('='*45)
    print('\n')
# Out:
# Judging (J) – Perceiving (P)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1048
#            1       0.76      0.74      0.75       687
#
#     accuracy                           0.81      1735
#    macro avg       0.80      0.79      0.80      1735
# weighted avg       0.80      0.81      0.80      1735
#
# Accuracy: 0.8051873198847262
# =============================================
#
#
# Prediction model : Random Forest
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.91      0.79      1048
#            1       0.74      0.41      0.53       687
#
#     accuracy                           0.71      1735
#    macro avg       0.72      0.66      0.66      1735
# weighted avg       0.72      0.71      0.69      1735
#
# Accuracy: 0.7089337175792507
# =============================================
#
#
# Prediction model : AdaBoost Algorithm
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81      1048
#            1       0.72      0.64      0.68       687
#
#     accuracy                           0.76      1735
#    macro avg       0.75      0.74      0.74      1735
# weighted avg       0.76      0.76      0.76      1735
#
# Accuracy: 0.7602305475504323
# =============================================
#
#
# Prediction model : XG Boost
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84      1048
#            1       0.78      0.70      0.74       687
#
#     accuracy                           0.80      1735
#    macro avg       0.80      0.79      0.79      1735
# weighted avg       0.80      0.80      0.80      1735
#
# Accuracy: 0.8046109510086455
# =============================================
#
#
# Prediction model : SVM
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.84      1048
#            1       0.82      0.63      0.71       687
#
#     accuracy                           0.80      1735
#    macro avg       0.80      0.77      0.78      1735
# weighted avg       0.80      0.80      0.79      1735
#
# Accuracy: 0.7965417867435158
# =============================================

# %% [markdown]
# ## Thinking (T) – Feeling (F)

# %%
print("Thinking (T) – Feeling (F) ")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['TF']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
for i in range(len(list(models))):
    model = list(models.values())[i]
    print(f"Prediction model : {list(models.keys())[i]}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print('='*35)
    print('\n')
# Out:
# Thinking (T) – Feeling (F)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       939
#            1       0.82      0.85      0.83       796
#
#     accuracy                           0.84      1735
#    macro avg       0.84      0.84      0.84      1735
# weighted avg       0.84      0.84      0.84      1735
#
# Accuracy: 0.8420749279538905
# ===================================
#
#
# Prediction model : Random Forest
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       939
#            1       0.80      0.77      0.78       796
#
#     accuracy                           0.80      1735
#    macro avg       0.80      0.80      0.80      1735
# weighted avg       0.80      0.80      0.80      1735
#
# Accuracy: 0.8040345821325648
# ===================================
#
#
# Prediction model : AdaBoost Algorithm
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80       939
#            1       0.77      0.76      0.76       796
#
#     accuracy                           0.79      1735
#    macro avg       0.78      0.78      0.78      1735
# weighted avg       0.79      0.79      0.79      1735
#
# Accuracy: 0.7855907780979827
# ===================================
#
#
# Prediction model : XG Boost
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       939
#            1       0.80      0.80      0.80       796
#
#     accuracy                           0.82      1735
#    macro avg       0.82      0.82      0.82      1735
# weighted avg       0.82      0.82      0.82      1735
#
# Accuracy: 0.8167146974063401
# ===================================
#
#
# Prediction model : SVM
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       939
#            1       0.82      0.82      0.82       796
#
#     accuracy                           0.84      1735
#    macro avg       0.84      0.84      0.84      1735
# weighted avg       0.84      0.84      0.84      1735
#
# Accuracy: 0.8380403458213257
# ===================================
