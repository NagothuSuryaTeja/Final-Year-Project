# %%
## importing Important modules
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")
from utils import save_object

# %%
print("Loading TF-IDF features...")
df = pd.read_csv("../Datasets/mbti_tfidf_features.csv")
# Out:
# Loading TF-IDF features...

# %% [markdown]
# IE

# %%
print("Introversion (I) – Extroversion (E)")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['IE']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
print(f"Prediction model : Logistic Regression")
model=LogisticRegression(n_jobs=-1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
print('='*35)
print('\n')
# Out:
# Introversion (I) – Extroversion (E)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       400
#            1       0.91      0.90      0.90      1335
#
#     accuracy                           0.85      1735
#    macro avg       0.79      0.80      0.79      1735
# weighted avg       0.85      0.85      0.85      1735
#
# Accuracy: 0.8518731988472622
# ...

# %%
save_object("../artifacts/model_ie.pkl",model)

# %% [markdown]
# NS

# %%
print("Intuition (N) – Sensing (S)")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['NS']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
print(f"Prediction model : Logistic Regression")
model=LogisticRegression(n_jobs=-1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
print('='*35)
print('\n')
# Out:
# Intuition (N) – Sensing (S)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.68      0.65       239
#            1       0.95      0.93      0.94      1496
#
#     accuracy                           0.90      1735
#    macro avg       0.78      0.81      0.79      1735
# weighted avg       0.90      0.90      0.90      1735
#
# Accuracy: 0.8968299711815562
# ...

# %%
save_object("../artifacts/model_ns.pkl",model)

# %% [markdown]
# TF

# %%
print("Thinking (T) - Feeling (F) ")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['TF']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
print(f"Prediction model : Logistic Regression")
LogisticRegression(n_jobs=-1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
print('='*35)
print('\n')
# Out:
# Thinking (T) - Feeling (F)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       939
#            1       0.82      0.85      0.83       796
#
#     accuracy                           0.84      1735
#    macro avg       0.84      0.84      0.84      1735
# weighted avg       0.84      0.84      0.84      1735
#
# Accuracy: 0.8420749279538905
# ...

# %%
save_object("../artifacts/model_tf.pkl",model)

# %% [markdown]
# JP

# %%
print("Judging (J) - Perceiving (P)")
X = df.drop(columns=['MBTI_type', 'IE', 'NS', 'TF', 'JP', 'original_posts', 'clean_posts'])
y = df['JP']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
smote = SMOTE(random_state=42) 
X_train, y_train = smote.fit_resample(X_train, y_train)
print(f"Prediction model : Logistic Regression")
LogisticRegression(n_jobs=-1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
print('='*35)
print('\n')
# Out:
# Judging (J) - Perceiving (P)
# Prediction model : Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1048
#            1       0.76      0.74      0.75       687
#
#     accuracy                           0.81      1735
#    macro avg       0.80      0.79      0.80      1735
# weighted avg       0.80      0.81      0.80      1735
#
# Accuracy: 0.8051873198847262
# ...

# %%
save_object("../artifacts/model_jp.pkl",model)
